# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# Removes the limit from the number of displayed columns and rows.
# This is so I can see the entire dataframe when I print it
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_rows', 200)

# %%
df = pd.read_csv("KickStarterProjects.csv")
print(f'There are {df.shape[0]} rows and {df.shape[1]} columns.')  # f-string

# I'm now going to look at 10 random rows
# I'm setting the random seed via np.random.seed so that
# I get the same random results every time
np.random.seed(1)
df.sample(n=10)
# Out:
# There are 378661 rows and 14 columns.
#                 ID                                               name  \
# 99838   1506962323                   2018 Comic Con/ Horror Con/ GMCC
# 15731   1079621785                        Ixion's The Four Disgracers
# 339459   799118140                      Irving Comics Inc. (Canceled)
# 100211  1508896926                                          Breakaway
# 170820  1869016023                             the Atomic Café Mobile
# 75113   1382708884                                             Shaken
# 258934   386894220  Happiness Ambassador Postcard Project Year: 20...
# 178566    19084902                      Unlikely Friends (Short Film)
# 33859   1171932479    Would you help a MONSTER make music? Yes or No?
# 278069   484824490                         Dracula: Son of the Dragon
#
#             subcategory      category currency    deadline     goal  \
# 99838               Art           Art      USD  10-10-2017    600.0
# ...

# %%
df.drop(['currency', 'goal'],axis=1,inplace=True)
df
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#             subcategory      category    deadline          launched  pledged  \
# ...

# %%
df.isnull().sum()
# Out:
# name                4
# subcategory         0
# category            0
# currency            0
# deadline            0
# goal                0
# launched            0
# pledged             0
# state               0
# backers             0
# country             0
# usd_pledged_real    0
# usd_goal_real       0
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# name                4
# subcategory         0
# category            0
# currency            0
# deadline            0
# goal                0
# launched            0
# pledged             0
# state               0
# backers             0
# country             0
# usd_pledged_real    0
# usd_goal_real       0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# name                4
# subcategory         0
# category            0
# currency            0
# deadline            0
# goal                0
# launched            0
# pledged             0
# state               0
# backers             0
# country             0
# usd_pledged_real    0
# usd_goal_real       0
# dtype: int64

# %%
df.isnull().sum(axis=0).value_counts()
# Out:
# 0    10
# 4     1
# dtype: int64

# %%
df.shape
# Out:
# (378661, 11)

# %%
df.head(2)
# Out:
#                                                      name     subcategory  \
# ID
# 1000002330                The Songs of Adelaide & Abullah          Poetry
# 1000003930  Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
#
#                 category currency    deadline     goal          launched  \
# ID
# 1000002330    Publishing      GBP  09-10-2015   1000.0  11-08-2015 12:12
# 1000003930  Film & Video      USD  01-11-2017  30000.0  02-09-2017 04:43
#
#             pledged   state  backers country  usd_pledged_real  usd_goal_real
# ID
# 1000002330      0.0  failed        0      GB               0.0        1533.95
# 1000003930   2421.0  failed       15      US            2421.0       30000.00

# %%
# most rows don't have missing values now
num_missing = df.isnull().sum(axis=0)
num_missing.value_counts()
# Out:
# 0    10
# 4     1
# dtype: int64

# %%
df[num_missing == 1]
# Out:
# /var/folders/l5/gcswsj051jj0jhx0pfjpn6c40000gn/T/ipykernel_17251/179645153.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[num_missing == 1]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# /var/folders/l5/gcswsj051jj0jhx0pfjpn6c40000gn/T/ipykernel_17251/179645153.py in <module>
# ----> 1 df[num_missing == 1]
#
# ~/.conda/envs/AIML/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3447         # Do we have a (boolean) 1d indexer?
#    3448         if com.is_bool_indexer(key):
# -> 3449             return self._getitem_bool_array(key)
#    3450
#    3451         # We are left with two options: a single key, and a collection of keys,
#
# ~/.conda/envs/AIML/lib/python3.8/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
# ...

# %%
df.drop(df[num_missing == 1], axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/l5/gcswsj051jj0jhx0pfjpn6c40000gn/T/ipykernel_17251/245659065.py in <module>
# ----> 1 df.drop(df[num_missing == 1], axis=0, inplace=True)
#
# ~/.conda/envs/AIML/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.conda/envs/AIML/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df = df.dropna(axis = 0, how ='any')

# %%
df
# Out:
#                                                          name  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 1000004038                                     Where is Hank?
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 1000011046  Community Film Project: The Art of Neighborhoo...
# ...                                                       ...
# 999976400   ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 999977640                                           The Tribe
# 999986353   Walls of Remedy- New lesbian Romantic Comedy f...
# 999987933                            BioDefense Education Kit
# 999988282                   Nou Renmen Ayiti!  We Love Haiti!
#
#                 subcategory      category    deadline          launched  \
# ID
# 1000002330           Poetry    Publishing  09-10-2015  11-08-2015 12:12
# ...

# %%
df.columns
# Out:
# Index(['name', 'subcategory', 'category', 'deadline', 'launched', 'pledged',
#        'state', 'backers', 'country', 'usd_pledged_real', 'usd_goal_real'],
#       dtype='object')

# %%
udf = pd.read_csv("KickStarterProjects.csv",index_col=0)

# %%
udf
# Out:
#                                                          name  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 1000004038                                     Where is Hank?
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 1000011046  Community Film Project: The Art of Neighborhoo...
# ...                                                       ...
# 999976400   ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 999977640                                           The Tribe
# 999986353   Walls of Remedy- New lesbian Romantic Comedy f...
# 999987933                            BioDefense Education Kit
# 999988282                   Nou Renmen Ayiti!  We Love Haiti!
#
#                 subcategory      category currency    deadline     goal  \
# ID
# 1000002330           Poetry    Publishing      GBP  09-10-2015   1000.0
# ...

# %%
df['state'].unique()
# Out:
# array(['failed', 'canceled', 'successful', 'live', 'undefined',
#        'suspended'], dtype=object)

# %%
df['state'=='failed'].shape().T
# Out:
# count     378657
# unique         6
# top       failed
# freq      197716
# Name: state, dtype: object

# %%
df['state'].value_counts()
# Out:
# failed        197716
# successful    133956
# canceled       38779
# undefined       3562
# live            2799
# suspended       1845
# Name: state, dtype: int64

# %%
df.describe().T
# Out:
#                      count          mean           std   min     25%      50%  \
# pledged           378657.0   9683.080264  9.563651e+04  0.00    30.0   620.00
# backers           378657.0    105.618544  9.071898e+02  0.00     2.0    12.00
# usd_pledged_real  378657.0   9059.018090  9.097382e+04  0.00    31.0   624.38
# usd_goal_real     378657.0  45454.245896  1.152956e+06  0.01  2000.0  5500.00
#
#                       75%           max
# pledged            4076.0  2.033899e+07
# backers              56.0  2.193820e+05
# usd_pledged_real   4050.0  2.033899e+07
# usd_goal_real     15500.0  1.663614e+08

# %%
np.median(df['backers'])
# Out:
# 12.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378657 entries, 1000002330 to 999988282
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              378657 non-null  object
#  1   subcategory       378657 non-null  object
#  2   category          378657 non-null  object
#  3   deadline          378657 non-null  object
#  4   launched          378657 non-null  object
#  5   pledged           378657 non-null  float64
#  6   state             378657 non-null  object
#  7   backers           378657 non-null  int64
#  8   country           378657 non-null  object
#  9   usd_pledged_real  378657 non-null  float64
#  10  usd_goal_real     378657 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 34.7+ MB

# %%
udf = udf.dropna(axis = 0, how ='any')

# %%
udf
# Out:
#                                                          name  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 1000004038                                     Where is Hank?
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 1000011046  Community Film Project: The Art of Neighborhoo...
# ...                                                       ...
# 999976400   ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 999977640                                           The Tribe
# 999986353   Walls of Remedy- New lesbian Romantic Comedy f...
# 999987933                            BioDefense Education Kit
# 999988282                   Nou Renmen Ayiti!  We Love Haiti!
#
#                 subcategory      category currency    deadline     goal  \
# ID
# 1000002330           Poetry    Publishing      GBP  09-10-2015   1000.0
# ...

# %%
# df['goal'] = pd.to_datetime(df['goal'])
# df['Joined year'] = df['Joined'].dt.year  # adding in a feature that's just the year
print(min(udf['goal']), max(udf['goal']))
udf['goal'].head()
# Out:
# 0.01 100000000.0
# ID
# 1000002330     1000.0
# 1000003930    30000.0
# 1000004038    45000.0
# 1000007540     5000.0
# 1000011046    19500.0
# Name: goal, dtype: float64

# %%
# replacing with scaled 
from sklearn.preprocessing import StandardScaler, MinMaxScaler
udf['goal'].hist(bins=20)
plt.title('goal before minmax scaling')
plt.show()

udf[['goal_scale']] = MinMaxScaler().fit_transform(
    udf[['goal']]
)

udf['goal_scale'].hist(bins=20)
plt.title('goal after minmax scaling')
plt.show()

# %%
udf
# Out:
#                                                          name  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 1000004038                                     Where is Hank?
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 1000011046  Community Film Project: The Art of Neighborhoo...
# ...                                                       ...
# 999976400   ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 999977640                                           The Tribe
# 999986353   Walls of Remedy- New lesbian Romantic Comedy f...
# 999987933                            BioDefense Education Kit
# 999988282                   Nou Renmen Ayiti!  We Love Haiti!
#
#                 subcategory      category currency    deadline     goal  \
# ID
# 1000002330           Poetry    Publishing      GBP  09-10-2015   1000.0
# ...

# %%
udf
# Out:
#                                                          name  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 1000004038                                     Where is Hank?
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 1000011046  Community Film Project: The Art of Neighborhoo...
# ...                                                       ...
# 999976400   ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 999977640                                           The Tribe
# 999986353   Walls of Remedy- New lesbian Romantic Comedy f...
# 999987933                            BioDefense Education Kit
# 999988282                   Nou Renmen Ayiti!  We Love Haiti!
#
#                 subcategory      category currency    deadline     goal  \
# ID
# 1000002330           Poetry    Publishing      GBP  09-10-2015   1000.0
# ...

# %%
# most rows don't have missing values now
num_missing = udf.isnull().sum(axis=1)
num_missing.value_counts()
# Out:
# 0    378657
# dtype: int64

# %%
udf
# Out:
#                                                          name  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 1000004038                                     Where is Hank?
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 1000011046  Community Film Project: The Art of Neighborhoo...
# ...                                                       ...
# 999976400   ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 999977640                                           The Tribe
# 999986353   Walls of Remedy- New lesbian Romantic Comedy f...
# 999987933                            BioDefense Education Kit
# 999988282                   Nou Renmen Ayiti!  We Love Haiti!
#
#                 subcategory      category currency    deadline     goal  \
# ID
# 1000002330           Poetry    Publishing      GBP  09-10-2015   1000.0
# ...

# %%
cols_to_log = ['usd_goal_real']
for colname in cols_to_log:
    plt.hist(df[colname], bins=50)
    plt.title(colname)
    plt.show()
    print(np.sum(df[colname] <= 0))
# Out:
# 0

# %%
plt.hist(np.log(udf['usd_goal_real'] + 1), 50)
plt.title('log(usd_goal_real + 1)')
plt.show()
plt.hist(np.arcsinh(udf['usd_goal_real']), 50)
plt.title('arcsinh(usd_goal_real)')
plt.show()
plt.hist(np.sqrt(udf['usd_goal_real']), 50)
plt.title('sqrt(usd_goal_real)')
plt.show()

# %%
udf
# Out:
#                                                          name  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 1000004038                                     Where is Hank?
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 1000011046  Community Film Project: The Art of Neighborhoo...
# ...                                                       ...
# 999976400   ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 999977640                                           The Tribe
# 999986353   Walls of Remedy- New lesbian Romantic Comedy f...
# 999987933                            BioDefense Education Kit
# 999988282                   Nou Renmen Ayiti!  We Love Haiti!
#
#                 subcategory      category currency    deadline     goal  \
# ID
# 1000002330           Poetry    Publishing      GBP  09-10-2015   1000.0
# ...

# %%
udf['launched_month'] = pd.to_datetime(udf['launched'])
udf['launched_month'] = udf['launched_month'].dt.month

# %%
udf['launched_month'].value_counts().sort_values(ascending=False)
# Out:
# 7     34477
# 1     34346
# 10    33409
# 3     32837
# 11    32135
# 8     31619
# 5     31573
# 9     31538
# 6     31381
# 4     31038
# 2     29876
# 12    24428
# Name: launched_month, dtype: int64

# %%
udf.groupby(['category'])['usd_pledged_real'].mean().sort_values(ascending=False)
# Out:
# category
# Design          24417.846732
# Technology      21151.171165
# Games           21042.491442
# Comics           6610.443828
# Film & Video     6158.073703
# Fashion          5712.450839
# Food             5113.669716
# Theater          4005.918099
# Music            3858.367608
# Photography      3571.909322
# Dance            3452.946356
# Publishing       3349.951931
# Art              3221.093567
# Journalism       2615.702568
# Crafts           1632.907282
# Name: usd_pledged_real, dtype: float64

# %%
df['name'].duplicated().sum()
# Out:
# 2935

# %%
df['name'].shape
# Out:
# (378657,)

# %%
df = pd.read_csv("insurance.csv")
print(f'There are {df.shape[0]} rows and {df.shape[1]} columns.')  # f-string

# I'm now going to look at 10 random rows
# I'm setting the random seed via np.random.seed so that
# I get the same random results every time
np.random.seed(1)
df.sample(n=10)
# Out:
# There are 1338 rows and 7 columns.
#       age     sex     bmi  children smoker     region      charges
# 559    19    male  35.530         0     no  northwest   1646.42970
# 1087   57    male  31.540         0     no  northwest  11353.22760
# 1020   51    male  37.000         0     no  southwest   8798.59300
# 460    49  female  36.630         3     no  southeast  10381.47870
# 802    21    male  22.300         1     no  southwest   2103.08000
# 298    31    male  34.390         3    yes  northwest  38746.35510
# 481    49    male  37.510         2     no  southeast   9304.70190
# 616    56  female  28.595         0     no  northeast  11658.11505
# 763    27    male  26.030         0     no  northeast   3070.80870
# 750    37  female  26.400         0    yes  southeast  19539.24300

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
plt.hist(df['charges'], bins=50 )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/l5/gcswsj051jj0jhx0pfjpn6c40000gn/T/ipykernel_17251/2466301395.py in <module>
# ----> 1 plt.hist(df['charges'], bins=50, reg=True)
#
# ~/.conda/envs/AIML/lib/python3.8/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2851         orientation='vertical', rwidth=None, log=False, color=None,
#    2852         label=None, stacked=False, *, data=None, **kwargs):
# -> 2853     return gca().hist(
#    2854         x, bins=bins, range=range, density=density, weights=weights,
#    2855         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~/.conda/envs/AIML/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
df['charges'].describe()
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %%
plt.hist(np.log(df['charges'] + 1), 50)
plt.title('log(charges + 1)')
plt.show()

# %%
df['charges'].median()
# Out:
# 9382.033

# %%
df[df['children']==0]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 9      60  female  25.840         0     no  northwest  28923.13692
# ...   ...     ...     ...       ...    ...        ...          ...
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [574 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
574/1338*100
# Out:
# 42.89985052316891

# %%
plt.hist(df['bmi_log'], 50)
plt.title('log(bmi + 1)')
plt.show()

# %%
df['bmi_log'] = np.log(df['bmi'] + 1)

# %%
dist_cols = [
    item for item in df.select_dtypes(include=np.number).columns
]

# %%
dist_cols
# Out:
# ['age', 'bmi', 'children', 'charges', 'bmi_log']

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges   bmi_log
# 0      19  female  27.900         0    yes  southwest  16884.92400  3.363842
# 1      18    male  33.770         1     no  southeast   1725.55230  3.548755
# 2      28    male  33.000         3     no  southeast   4449.46200  3.526361
# 3      33    male  22.705         0     no  northwest  21984.47061  3.165686
# 4      32    male  28.880         0     no  northwest   3866.85520  3.397189
# ...   ...     ...     ...       ...    ...        ...          ...       ...
# 1333   50    male  30.970         3     no  northwest  10600.54830  3.464798
# 1334   18  female  31.920         0     no  northeast   2205.98080  3.494080
# 1335   18  female  36.850         0     no  southeast   1629.83350  3.633631
# 1336   21  female  25.800         0     no  southwest   2007.94500  3.288402
# 1337   61  female  29.070         0    yes  northwest  29141.36030  3.403528
#
# [1338 rows x 8 columns]

# %%
for i in range(len(dist_cols)):
    plt.subplot(12, 3, i + 1)
    plt.hist(df[dist_cols[i]], bins=50)
    # sns.histplot(data=df3, x=dist_cols[i], kde=True)  # you can comment the previous line and run this one to get distribution curves
    plt.tight_layout()
    plt.title(dist_cols[i], fontsize=25)

plt.show()
# Out:
# /var/folders/l5/gcswsj051jj0jhx0pfjpn6c40000gn/T/ipykernel_17251/383404275.py:5: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges   bmi_log
# 0      19  female  27.900         0    yes  southwest  16884.92400  3.363842
# 1      18    male  33.770         1     no  southeast   1725.55230  3.548755
# 2      28    male  33.000         3     no  southeast   4449.46200  3.526361
# 3      33    male  22.705         0     no  northwest  21984.47061  3.165686
# 4      32    male  28.880         0     no  northwest   3866.85520  3.397189
# ...   ...     ...     ...       ...    ...        ...          ...       ...
# 1333   50    male  30.970         3     no  northwest  10600.54830  3.464798
# 1334   18  female  31.920         0     no  northeast   2205.98080  3.494080
# 1335   18  female  36.850         0     no  southeast   1629.83350  3.633631
# 1336   21  female  25.800         0     no  southwest   2007.94500  3.288402
# 1337   61  female  29.070         0    yes  northwest  29141.36030  3.403528
#
# [1338 rows x 8 columns]

# %%
df['region'].groupBy(.value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
df.groupby(['region'])['charges'].median().sort_values(ascending=False)
# Out:
# region
# northeast    10057.652025
# southeast     9294.131950
# northwest     8965.795750
# southwest     8798.593000
# Name: charges, dtype: float64

# %%
# df['is_GK'] = df['Position'] == 'GK'  # for hue
# cols_to_exclude = ['International Reputation', 'Weak Foot', 'Skill Moves']
sns.pairplot(df[[colname for colname in df.columns]])
# df.drop(['is_GK'], axis=1, inplace=True)

# %%
df.corr
# Out:
# <bound method DataFrame.corr of       age     sex     bmi  children smoker     region      charges   bmi_log
# 0      19  female  27.900         0    yes  southwest  16884.92400  3.363842
# 1      18    male  33.770         1     no  southeast   1725.55230  3.548755
# 2      28    male  33.000         3     no  southeast   4449.46200  3.526361
# 3      33    male  22.705         0     no  northwest  21984.47061  3.165686
# 4      32    male  28.880         0     no  northwest   3866.85520  3.397189
# ...   ...     ...     ...       ...    ...        ...          ...       ...
# 1333   50    male  30.970         3     no  northwest  10600.54830  3.464798
# 1334   18  female  31.920         0     no  northeast   2205.98080  3.494080
# 1335   18  female  36.850         0     no  southeast   1629.83350  3.633631
# 1336   21  female  25.800         0     no  southwest   2007.94500  3.288402
# 1337   61  female  29.070         0    yes  northwest  29141.36030  3.403528
#
# ...

# %%
correlation = df.corr() # creating a 2-D Matrix with correlation plots


#%%

# Uncomment the following code for information of the arguments
# help(sns.heatmap)
plt.figure(figsize=(15, 7))
sns.heatmap(correlation, annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
#  7   bmi_log   1338 non-null   float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 83.8+ KB

# %%
df.sex = df.sex.astype('category')

# %%
df.smoker = df.smoker.astype('category')

# %%
df.region = df.region.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   category
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   category
#  5   region    1338 non-null   category
#  6   charges   1338 non-null   float64
#  7   bmi_log   1338 non-null   float64
# dtypes: category(3), float64(3), int64(2)
# memory usage: 56.8 KB

# %%
pd.get_dummies(df['region'], drop_first=True)
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
udf=df.copy()
X = udf.drop(["charges"], axis=1)
y = udf["charges"]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
print("Number of rows in train data =", x_train.shape[0])
print("Number of rows in test data =", x_test.shape[0])
# Out:
# Number of rows in train data = 936
# Number of rows in test data = 402

# %%
# this will help in making the Python code more structured automatically (good coding practice)
# %load_ext nb_black

# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# Removes the limit for the number of displayed columns
pd.set_option("display.max_columns", None)
# Sets the limit for the number of displayed rows
pd.set_option("display.max_rows", 200)

# to split the data into train and test
from sklearn.model_selection import train_test_split

# to build linear regression_model
from sklearn.linear_model import LinearRegression

# to check model performance
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
X = pd.get_dummies(
    X,
    columns=X.select_dtypes(include=["object", "category"]).columns.tolist(),
    drop_first=True,
)

X.head()
# Out:
#    age     bmi  children   bmi_log  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  3.363842         0           1                 0
# 1   18  33.770         1  3.548755         1           0                 0
# 2   28  33.000         3  3.526361         1           0                 0
# 3   33  22.705         0  3.165686         1           0                 1
# 4   32  28.880         0  3.397189         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
lin_reg_model = LinearRegression()
lin_reg_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
coef_df = pd.DataFrame(
    np.append(lin_reg_model.coef_, lin_reg_model.intercept_),
    index=x_train.columns.tolist() + ["Intercept"],
    columns=["Coefficients"],
)
coef_df
# Out:
#                   Coefficients
# age                 250.579263
# bmi                  59.603700
# children            343.753802
# bmi_log            8263.887018
# sex_male           -281.837228
# smoker_yes        24063.691319
# region_northwest   -340.800324
# region_southeast   -916.823488
# region_southwest   -897.779201
# Intercept        -31326.757077

# %%
# function to compute adjusted R-squared
def adj_r2_score(predictors, targets, predictions):
    r2 = r2_score(targets, predictions)
    n = predictors.shape[0]
    k = predictors.shape[1]
    return 1 - ((1 - r2) * (n - 1) / (n - k - 1))


# function to compute MAPE
def mape_score(targets, predictions):
    return np.mean(np.abs(targets - predictions) / targets) * 100


# function to compute different metrics to check performance of a regression model
def model_performance_regression(model, predictors, target):
    """
    Function to compute different metrics to check regression model performance

    model: regressor
    predictors: independent variables
    target: dependent variable
    """

    # predicting using the independent variables
    pred = model.predict(predictors)

    r2 = r2_score(target, pred)  # to compute R-squared
    adjr2 = adj_r2_score(predictors, target, pred)  # to compute adjusted R-squared
    rmse = np.sqrt(mean_squared_error(target, pred))  # to compute RMSE
    mae = mean_absolute_error(target, pred)  # to compute MAE
    mape = mape_score(target, pred)  # to compute MAPE

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {
            "RMSE": rmse,
            "MAE": mae,
            "R-squared": r2,
            "Adj. R-squared": adjr2,
            "MAPE": mape,
        },
        index=[0],
    )

    return df_perf

# %%
# Checking model performance on train set
print("Training Performance\n")
lin_reg_model_train_perf = model_performance_regression(lin_reg_model, x_train, y_train)
lin_reg_model_train_perf
# Out:
# Training Performance
#           RMSE          MAE  R-squared  Adj. R-squared       MAPE
# 0  6036.151135  4200.541215   0.754836        0.752453  43.644505

# %%
# Checking model performance on test set
print("Test Performance\n")
lin_reg_model_test_perf = model_performance_regression(lin_reg_model, x_test, y_test)
lin_reg_model_test_perf
# Out:
# Test Performance
#           RMSE         MAE  R-squared  Adj. R-squared       MAPE
# 0  6051.877226  4190.45752    0.74156        0.735627  42.633791

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

reg = LinearRegression()

# Build step forward feature selection
sfs = SFS(
    reg,
    k_features=x_train.shape[1],
    forward=True,  # k_features denotes "Number of features to select"
    floating=False,
    scoring="r2",
    n_jobs=-1,
    verbose=2,
    cv=5,
)

# Perform SFFS
sfs = sfs.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of   9 | elapsed:    3.0s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    3.0s finished
#
# [2021-11-14 23:22:32] Features: 1/9 -- score: 0.6234900046866103[Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.1s finished
#
# [2021-11-14 23:22:32] Features: 2/9 -- score: 0.7227858451502291[Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    0.1s finished
#
# [2021-11-14 23:22:32] Features: 3/9 -- score: 0.7467862657269878[Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# ...

# %%
# to plot the performance with addition of each feature
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs

fig1 = plot_sfs(sfs.get_metric_dict(), kind="std_err", figsize=(15, 5))
plt.title("Sequential Forward Selection (w. StdErr)")
plt.xticks(rotation=90)
plt.show()

# %%
reg = LinearRegression()

# # Build step forward feature selection
sfs = SFS(
    reg,
    k_features=3,
    forward=True,
    floating=False,
    scoring="r2",
    n_jobs=-1,
    verbose=2,
    cv=5,
)

# Perform SFFS
sfs = sfs.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of   9 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    0.2s finished
#
# [2021-11-14 23:23:44] Features: 1/3 -- score: 0.6234900046866103[Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.1s finished
#
# [2021-11-14 23:23:44] Features: 2/3 -- score: 0.7227858451502291[Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    0.1s finished
#
# [2021-11-14 23:23:44] Features: 3/3 -- score: 0.7467862657269878

# %%
# Let us select features which are important
feat_cols = list(sfs.k_feature_idx_)
print(feat_cols)
# Out:
# [0, 3, 5]

# %%
x_train.columns[feat_cols]
# Out:
# Index(['age', 'bmi_log', 'smoker_yes'], dtype='object')

# %%
x_train_final = x_train[x_train.columns[feat_cols]]

# %%
# Creating new x_test with the same 20 variables that we selected for x_train
x_test_final = x_test[x_train_final.columns]

# %%
# let us check the coefficients and intercept of the model
# Fitting linear model
lin_reg_model2 = LinearRegression()
lin_reg_model2.fit(x_train_final, y_train)
coef_df = pd.DataFrame(
    np.append(lin_reg_model2.coef_.flatten(), lin_reg_model2.intercept_),
    index=x_train_final.columns.tolist() + ["Intercept"],
    columns=["Coefficients"],
)
coef_df
# Out:
#             Coefficients
# age           251.524569
# bmi_log      9614.044639
# smoker_yes  24030.857143
# Intercept  -34487.287531

# %%
# model performance on train set
print("Training Performance\n")
lin_reg_model2_train_perf = model_performance_regression(
    lin_reg_model2, x_train_final, y_train
)
lin_reg_model2_train_perf
# Out:
# Training Performance
#           RMSE          MAE  R-squared  Adj. R-squared       MAPE
# 0  6063.592149  4240.370081   0.752602        0.751806  45.266168

# %%
# model performance on test set
print("Test Performance\n")
lin_reg_model2_test_perf = model_performance_regression(
    lin_reg_model2, x_test_final, y_test
)
lin_reg_model2_test_perf
# Out:
# Test Performance
#           RMSE          MAE  R-squared  Adj. R-squared       MAPE
# 0  6117.149294  4239.625795   0.735955        0.733965  44.705382

# %%
# training performance comparison

models_train_comp_df = pd.concat(
    [lin_reg_model_train_perf.T, lin_reg_model2_train_perf.T],
    axis=1,
)

models_train_comp_df.columns = [
    "Linear Regression sklearn",
    "Linear Regression sklearn (SFS features)",
]

print("Training performance comparison:")
models_train_comp_df
# Out:
# Training performance comparison:
#                 Linear Regression sklearn  \
# RMSE                          6036.151135
# MAE                           4200.541215
# R-squared                        0.754836
# Adj. R-squared                   0.752453
# MAPE                            43.644505
#
#                 Linear Regression sklearn (SFS features)
# RMSE                                         6063.592149
# MAE                                          4240.370081
# R-squared                                       0.752602
# Adj. R-squared                                  0.751806
# MAPE                                           45.266168

# %%
# test performance comparison

models_test_comp_df = pd.concat(
    [lin_reg_model_test_perf.T, lin_reg_model2_test_perf.T],
    axis=1,
)

models_test_comp_df.columns = [
    "Linear Regression sklearn",
    "Linear Regression sklearn (SFS features)",
]

print("Test performance comparison:")
models_test_comp_df
# Out:
# Test performance comparison:
#                 Linear Regression sklearn  \
# RMSE                          6051.877226
# MAE                           4190.457520
# R-squared                        0.741560
# Adj. R-squared                   0.735627
# MAPE                            42.633791
#
#                 Linear Regression sklearn (SFS features)
# RMSE                                         6117.149294
# MAE                                          4239.625795
# R-squared                                       0.735955
# Adj. R-squared                                  0.733965
# MAPE                                           44.705382
